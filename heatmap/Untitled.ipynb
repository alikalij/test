# %%
# libraries
import seaborn as sns
import pandas as pd
import numpy as np
 
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])

# plot a heatmap with annotation
sns.heatmap(df, annot=True, annot_kws={"size": 7})
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.942540  0.899854  0.818171  0.128659  0.561643  0.339544  0.429175
# 1  0.360259  0.369603  0.293464  0.893671  0.900609  0.289189  0.818399
# 2  0.994336  0.930773  0.974719  0.246889  0.363474  0.436161  0.319754
# 3  0.638532  0.735185  0.691875  0.160560  0.218598  0.758145  0.343115
# 4  0.769217  0.652704  0.436058  0.866587  0.543928  0.729739  0.032176
# 5  0.955047  0.306801  0.753168  0.318750  0.207430  0.770852  0.352097
# 6  0.191011  0.942650  0.214329  0.027780  0.512132  0.015170  0.620790
# 7  0.494518  0.167300  0.897276  0.178928  0.228935  0.956788  0.010235
# 8  0.414236  0.935382  0.234141  0.948791  0.801322  0.730977  0.060777
# 9  0.578051  0.035153  0.257363  0.737275  0.056851  0.894714  0.839719
#
#           h         i         j
# 0  0.476013  0.764640  0.988800
# 1  0.204653  0.177521  0.545140
# 2  0.364807  0.584933  0.445155
# 3  0.389102  0.193936  0.293058
# ...

# %%
# Create a dataset
df = pd.read_csv('dff.csv')
df = df.set_index(df.columns[0])
df=df.T
df1.T
# plot a heatmap with annotation
ax=sns.heatmap(df, annot=True, annot_kws={"size": 7})
ax.invert_yaxis()

# %%
# Create a dataset
df = pd.read_csv('dff.csv')
df = df.set_index(df.columns[0])

# %%
# Create a dataset
df2 = pd.read_csv('dff2.csv')
df2 = df2.set_index(df2.columns[0])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
#color mako viridis

fig, (ax,ax2) = plt.subplots(ncols=2,figsize=(20,8))
fig.subplots_adjust(wspace=0.01)
sns.heatmap(df, cmap="rocket", ax=ax, cbar=False,annot=True, annot_kws={"size": 9})
fig.colorbar(ax.collections[0], ax=ax,location="left", use_gridspec=False, pad=0.2)
sns.heatmap(df2, cmap="icefire", ax=ax2, cbar=False,annot=True, annot_kws={"size": 9})
fig.colorbar(ax2.collections[0], ax=ax2,location="right", use_gridspec=False, pad=0.2,)
ax2.yaxis.tick_right()
ax2.tick_params(rotation=0)
plt.show()

# %%
df
# Out:
#            A         B         C         D
# 0   0.275549  0.854254  0.941448  0.908629
# 1   0.595890  0.213036  0.384160  0.553045
# 2   0.133884  0.882421  0.211287  0.058741
# 3   0.985728  0.698370  0.134117  0.130613
# 4   0.126492  0.237334  0.802397  0.871513
# 5   0.130275  0.573457  0.889590  0.746440
# 6   0.355155  0.772772  0.586643  0.116215
# 7   0.911440  0.611507  0.206837  0.552397
# 8   0.670983  0.326811  0.623828  0.739131
# 9   0.026511  0.356956  0.907268  0.414259
# 10  0.582861  0.339237  0.045197  0.490895
# 11  0.102854  0.475785  0.977701  0.430821
# 12  0.421164  0.321107  0.130183  0.714250
# 13  0.171136  0.064871  0.776811  0.402253
# 14  0.211870  0.263812  0.260788  0.053174
# 15  0.436451  0.380572  0.363095  0.011927
# 16  0.831409  0.207145  0.573605  0.863320
# 17  0.947242  0.147685  0.649158  0.150219
# 18  0.254988  0.746392  0.314378  0.627895
# 19  0.259655  0.979782  0.538247  0.245535
# 20  0.808063  0.939727  0.276932  0.828153
# ...

# %%
from bioinfokit import analys, visuz
# load dataset as pandas dataframe
# Create a dataset
df12 = pd.read_csv('hm_cot.csv')
df12.head(2)


# set gene names as index
df12 = df12.set_index(df.columns[0])
df12.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 9>()
#       5 df12.head(2)
#       8 # set gene names as index
# ----> 9 df12 = df12.set_index(df.columns[0])
#      10 df12.head(2)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# ...
